# %%
# %pip install pygam
import pandas as pd
from pygam import LinearGAM, s


# Load the training data
train_data = pd.read_csv('assignment_data_train.csv', parse_dates=['Timestamp'], index_col='Timestamp')

# Resample data to hourly frequency, summing the number of trips
train_data = train_data.resample('H').sum()

# Step 2: Define the forecasting model
X = train_data.index.hour.values.reshape(-1, 1)
y = train_data['trips']

# Initialize and fit the model
model = LinearGAM(s(0)).fit(X, y)
modelFit = model

# Step 3: Forecasting
test_data = pd.read_csv('assignment_data_test.csv', parse_dates=['Timestamp'], index_col='Timestamp')
test_data = test_data.resample('H').sum()

X_test = test_data.index.hour.values.reshape(-1, 1)
pred = model.predict(X_test)

# Save predictions to a CSV file (optional)
prediction_df = pd.DataFrame(data=pred, index=test_data.index, columns=['predicted_number_of_trips'])
prediction_df.to_csv('predictions.csv')
# Out:
# Requirement already satisfied: pygam in c:\users\zkpet\anaconda3\lib\site-packages (0.9.1)
# Requirement already satisfied: numpy>=1.25 in c:\users\zkpet\anaconda3\lib\site-packages (from pygam) (1.26.4)
# Requirement already satisfied: progressbar2<5.0.0,>=4.2.0 in c:\users\zkpet\anaconda3\lib\site-packages (from pygam) (4.5.0)
# Requirement already satisfied: scipy<1.12,>=1.11.1 in c:\users\zkpet\anaconda3\lib\site-packages (from pygam) (1.11.4)
# Requirement already satisfied: python-utils>=3.8.1 in c:\users\zkpet\anaconda3\lib\site-packages (from progressbar2<5.0.0,>=4.2.0->pygam) (3.9.1)
# Requirement already satisfied: typing_extensions>3.10.0.2 in c:\users\zkpet\anaconda3\lib\site-packages (from python-utils>=3.8.1->progressbar2<5.0.0,>=4.2.0->pygam) (4.11.0)
# Note: you may need to restart the kernel to use updated packages.
# <positron-console-cell-6>:10: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# <positron-console-cell-6>:22: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
